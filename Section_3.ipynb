# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import os
import matplotlib.colors as colors
import matplotlib.cm as cm

# %%
#np.set_printoptions(threshold=np.nan)
#np.set_printoptions(threshold=50)
#pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
#pd.set_option('display.width', 1000)

# %%
df_sellsperyear = pd.DataFrame(df.groupby("year").size()).reset_index()
fig = plt.figure(figsize=(25,15))
plt.bar(df_sellsperyear.year, df_sellsperyear[0])
plt.title("Sales of Opiods per Year", fontsize=20)
plt.xlabel('Year', fontsize=18)
plt.ylabel('Sales', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
fig = plt.figure(figsize=(60,30))


df_sellsperstate = pd.DataFrame(df.groupby("BUYER_STATE").size()).reset_index()
df_sellsperstate["population"] = [710438, 4887871, 3013825, 7171646, 39557045, 5695564, 3572665, 702445, 967171, 21299325, 10519475,
                                165718, 1420491, 3156145, 1754208, 12741080, 6691878, 2911505, 4468402, 4659978, 6902149, 6042718,
                                 1338404, 9995915, 5611179, 6126452, 0, 2986530, 1062305, 10383620, 760077, 1929268, 1356458, 8908520,
                                2095428, 3034392, 19542209, 11689442, 3943079, 4190713, 12807060, 3195153, 1057315, 5084127, 882235,
                                6770010, 28701845, 3161105, 8517685, 104914, 626299, 7535591, 5813568, 1805832, 577737]
df_sellsperstate["transactions_per_person"] =  df_sellsperstate[0]/df_sellsperstate["population"]

plt.subplot(1, 2, 1)
plt.bar(df_sellsperstate.BUYER_STATE, df_sellsperstate[0])
plt.title("Transaction of Opiods per State", fontsize=25)
plt.xlabel('State', fontsize=18)
plt.ylabel('Number of Transaction', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.subplot(1,2,2)
plt.bar(df_sellsperstate.BUYER_STATE, df_sellsperstate["transactions_per_person"])
plt.title("Transaction per Person in each State", fontsize=25)
plt.xlabel('State', fontsize=18)
plt.ylabel('Number of Transaction', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
df_companies = pd.DataFrame(df.groupby("Revised_Company_Name").size()).reset_index()
df_companies = df_companies[df_companies[0]>= 5000] #filter for only the biggest sellers
fig = plt.figure(figsize=(25,15))
plt.bar(df_companies["Revised_Company_Name"], df_companies[0])
plt.title("Sales of Opiods per Company", fontsize=20)
plt.xlabel('Companies', fontsize=18)
plt.ylabel('Transactions', fontsize=18)
plt.xticks(fontsize=14, rotation=90)
plt.yticks(fontsize=14)
plt.show()
